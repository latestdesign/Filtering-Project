# %% [markdown]
# **TP Filtres de Kalman d'ensemble**
#
# L'objectif de ce TP est la mise en place d'un système d'assimilation de données par filtres de Kalman d'ensemble, pour le système de Lorenz 63 :
#
# $$ \dot{x} = \sigma (y-x) $$
# $$ \dot{y} = x (\rho -z ) -y $$
# $$ \dot{z} = xy -\beta z $$
# Les paramètres par défaut sont $\sigma = 10$, $\rho = 28$, $\beta=8/3$, et la condition initiale $(1.5, -1.5, 21)$.
#
# *Sources*: ce TP s'inspire des notebooks d'E. Cosme (UGA).

# %%
import numpy as np
import math
import scipy as scp
import scipy.sparse as scps
import scipy.sparse.linalg as sla
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#-------------------------------------------------------
# Lorenz 63
#-------------------------------------------------------

class Model:
    def __init__( self, nmembers = 1 ):
        self.nmembers = nmembers
        self.nx = 3                     
        self.sigma = 10.
        self.rho = 28.
        self.beta = 8./3.
        self.dt = 0.01
        self.x0 = np.array([1.5, -1.5, 20.])
        self.xvar = self.initial_condition() 
        self.xvar_series = []
        self.time = 0.
        self.time_series = []
        
    def initial_condition(self):
        """Condition initiale"""
        if self.nmembers == 1:
            xout = self.x0.reshape((self.nx, 1))
        else:
            p0 = 3.*np.eye(self.nx)
            xout = np.random.multivariate_normal(self.x0, p0, self.nmembers).T
        return xout

    def rhs(self,x_in):
        """Second membre"""
        x_out=np.zeros_like(x_in)
        x_out[0,]=self.sigma*(x_in[1,]-x_in[0,])
        x_out[1,]=self.rho*x_in[0,]-x_in[1,]-x_in[0,]*x_in[2,]
        x_out[2,]=x_in[0,]*x_in[1,]-self.beta*x_in[2,]
        return x_out

    def forward(self, nstep_in):
        """Intégration temporelle"""
        self.xvar_series = np.zeros((self.nx, nstep_in, self.nmembers))
        self.time_series = np.zeros(nstep_in)
        for it in range(nstep_in):
            self.xvar_series[:,it,:] = self.xvar
            self.time_series[it] = self.time
            k1=self.rhs(self.xvar)*self.dt
            xtmp=self.xvar+0.5*k1
            k2=self.rhs(xtmp)*self.dt
            xtmp=self.xvar+0.5*k2
            k3=self.rhs(xtmp)*self.dt
            xtmp=self.xvar+k2
            k4=self.rhs(xtmp)*self.dt
            self.xvar+=(k1+2*k2+2*k3+k4)/6.
            self.time += self.dt
  
    def plot(self):
        """Affichage"""
        plt.figure(figsize=(12,8))
        for ix in range(self.nx):
            pnum = 311+ix
            plt.subplot(pnum)
            for ie in range(self.nmembers):
                plt.plot(self.time_series[:],self.xvar_series[ix,:,ie],'black',linewidth=1.)
        plt.show()

# %%
# Illustration du système de Lorenz 63 #
lorenz_test = Model()
lorenz_test.forward(3000)
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection='3d')
ax.plot(lorenz_test.xvar_series[0,:,0], lorenz_test.xvar_series[1,:,0], lorenz_test.xvar_series[2,:,0])
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")
ax.set_title("Système de Lorenz")
plt.show()

# %%
# Simulation de référence
ntime=2000
lorenz_ref = Model()
lorenz_ref.forward(ntime)
lorenz_ref.plot()
true_state = lorenz_ref.xvar_series
true_time = lorenz_ref.time_series

# %%
# Ebauche : erreur sur l'état initial et le paramètre rho
background_state = np.array([0.5, -3., 22.])
lorenz_bkg = Model()
lorenz_bkg.rho = 29.
lorenz_bkg.x0 = np.copy(background_state)
lorenz_bkg.xvar = lorenz_test.initial_condition()
lorenz_bkg.forward(ntime)
plt.figure(figsize=(12,8))
for ix in range(3):
    pnum = 311+ix
    plt.subplot(pnum)
    plt.plot(true_time,true_state[ix,:,0],'black',linewidth=1.,label='Reference')
    plt.plot(lorenz_bkg.time_series,lorenz_bkg.xvar_series[ix,:,0],'red',linewidth=1.,label='Background')
    plt.legend()
plt.show()

# %% [markdown]
# **Analyse par EnKF/ETKF**
#
#
# On note ${\bf E}^f\in \mathbb{R}^{m\times n}$ l'ensemble de prévision, $\bar{\bf x}^f=\frac{1}{n}{\bf E}^f{\bf e}\in \mathbb{R}^{m}$ sa moyenne, et ${\bf A}^f={\bf E}^f({\bf I}_n-\frac{1}{n}{\bf  e}{\bf  e}^T)\in \mathbb{R}^{m\times n}$, la matrice d'anomalies, avec ${\bf  e}=[1,\dots,1]^T$.
#
# On souhaite réaliser l'étape d'analyse du filtre de Kalman d'ensemble (EnKF), et de sa variante déterministe (ETKF). Ces deux analyses se décomposent en deux étapes :
#
# 1- Mise à jour de la moyenne de l'ensemble :
# $$
#     \bar{\bf x}^a=\bar{\bf x}^f+ {{\bf A}^f{\bf G}}{\bf R}^{-\frac{1}{2}}({\bf y}-{\bf H}\bar{\bf x}^f)/\sqrt{n-1},
# $$
#
# avec ${\bf y}$ le vecteur d'observations, ${\bf H}$ l'opérateur d'observation,
# ${\bf G}={{\bf S}^T}({\bf I}_p+{{\bf S}}{{\bf S}^T})^{-1}$,
# et ${\bf S}={\bf R}^{-\frac{1}{2}}{\bf H}{{\bf A}^f}/\sqrt{n-1}$.
#
#
# 2- Mise à jour de la matrice d'anomalies :
# $$
# {\bf A}^a={\bf A}^f+ {\bf A}^f {\bf T},
# $$
# avec ${\bf T}$ définie par :
#
#      a - EnKF :
#
# $${\bf T}={\bf G}({\bf D}-{\bf S}),$$
#
# avec  ${\bf D}={\bf R}^{-\frac{1}{2}}\tilde{\bf D}/\sqrt{n-1}$, $\tilde{\bf D}$ perturbations gaussiennes telles que $\tilde{\bf D}{\bf e}=0$, et $\tilde{\bf D}\tilde{\bf D}^T/(n-1)\rightarrow {\bf R}$.
#
#      b - ETKF :
#
#
# $${\bf T}=({\bf I}_n+{\bf S}^T{\bf S})^{-\frac{1}{2}}-{\bf I}_n.$$
#
#
# L'ensemble d'analyse est alors obtenu par
# $${\bf E}^a={\bf x}^a{\bf e}^T+{\bf A}^a.$$
#
# Plus d'information dans Sakov et al. (2010).

# %%
# Analyse par EnKF ou ETKF #
def analysis(Ef,y,Robs,H,methode,nobs):
    # Paramètres d'entrée :
    # Ef : ensemble de prévision
    # y : vecteur d'observations
    # Robs : matrice de covariance d'erreur d'observation
    # H : operateur d'observation
    # methode : 1 ETKF, sinon EnKF
    #################################
    # Sortie : 
    # Ea : ensemble d'analyse
    n = Ef.shape[1]
    e = np.ones((n, 1))

    xf = Ef @ e / n  # moyenne d'état de l'ensemble de prévision
    Af = Ef - xf @ e.T

    inv_sqrtR = np.linalg.inv(scp.linalg.sqrtm(Robs))
    S = inv_sqrtR @ H @ Af / math.sqrt(n - 1)
    mid = np.eye(nobs) + S @ S.T
    mid_inv = np.linalg.solve(mid, np.eye(nobs))
    G = S.T @ mid_inv

    xa = xf + Af @ G @ inv_sqrtR @ (y - H @ xf) / math.sqrt(n - 1)
    if methode == 1:
        mid2 = np.eye(n) + S.T @ S
        eigval, eigvec = np.linalg.eigh(mid2)
        # eigval = np.clip(eigval, 1e-9, None)
        T = eigvec @ (np.diag(1.0 / np.sqrt(eigval))) @ eigvec.T
        T = T - np.eye(n)
    else:
        Dtilde = np.random.multivariate_normal(np.zeros(nobs), Robs, n).T
        D = inv_sqrtR @ Dtilde / math.sqrt(n - 1)
        T = G @ (D - S)
    Aa = Af + Af @ T
    Ea = xa @ e.T + Aa

    return Ea

# %%
# Paramètres
methode = 1 # 0 pourEnKF, 1 pour ETKF
nmem = 30
pas_assim = 50
so2 = 9.e-2
nvarobs = [0,2]

# Cycle d'assimilation par filtres de Kalman d'ensemble
def run_assimilation(methode, nmem, so2, pas_assim, nvarobs):
    # Opérateur d'observation
    nobs = len(nvarobs)
    Robs = so2*np.eye(nobs)
    H = np.zeros((nobs,3))
    for i in range(nobs):
        H[i,nvarobs[i]]=1.

    # Fréquence d'assimilation
    assim_steps = range(25,ntime,pas_assim)
    nassim = len(assim_steps)
    lencycle = np.hstack((assim_steps[0], np.ediff1d(assim_steps)))

    # Initialisation du modèle d'assimilation
    lorenz_assim = Model(nmembers=nmem)
    lorenz_assim.x0 = np.copy(background_state)
    lorenz_assim.xvar = lorenz_assim.initial_condition()
    lorenz_assim.rho = 29.

    time1 = np.empty(ntime)
    xvar1 = np.empty((3, ntime, nmem))
    rms_error = np.zeros(nassim)
    var_error = np.zeros(nassim)

    for ic in range(nassim):
        ## Forecast
        if ic == 0:
            nstep = assim_steps[0]
        else:
            nstep = assim_steps[ic] - assim_steps[ic-1]
            
        lorenz_assim.forward(nstep)
        
        if ic == 0:
            time1 = lorenz_assim.time_series
            xvar1 = lorenz_assim.xvar_series
        else:
            time1 = np.hstack(( time1, lorenz_assim.time_series ))
            xvar1 = np.concatenate( ( xvar1, lorenz_assim.xvar_series ), axis = 1 )
        
        ## Analysis
        obs_index = np.argwhere( true_time == lorenz_assim.time )
        y=np.transpose(true_state[nvarobs, obs_index, 0] +np.dot(math.sqrt(so2)*np.eye(nobs),np.random.normal(0,1,(nobs,))))
        lorenz_assim.xvar = analysis(lorenz_assim.xvar,y,Robs,H,methode,nobs)

        rms_error[ic] = np.sqrt(np.mean((np.mean(lorenz_assim.xvar, axis=1) - true_state[:,obs_index,0].flatten())**2/np.mean(true_state[:,obs_index,0].flatten()**2)))
        var_error[ic] = np.mean(np.var(lorenz_assim.xvar, axis=1))

    ## Last cycle
    lorenz_assim.forward( ntime - assim_steps[-1] )
    time1 = np.hstack(( time1, lorenz_assim.time_series ))
    xvar1 = np.concatenate( ( xvar1, lorenz_assim.xvar_series ), axis = 1 )
    return time1, xvar1, rms_error, var_error

## Plots
time1, xvar1, _, _ = run_assimilation(methode, nmem, so2, pas_assim, nvarobs)
xvarmean = np.mean(xvar1, axis=2)

plt.figure(figsize=(12,8))
for ix in range(3):
    pnum = 311+ix
    plt.subplot(pnum)
    plt.plot(true_time,true_state[ix,:,0],'black',linewidth=1.,label='Reference')
    plt.plot(time1, xvarmean[ix,:],'red',linewidth=1.,label='EnKF')
    plt.legend()
    for ie in range(nmem):
        plt.plot(time1, xvar1[ix,:, ie],'blue',linewidth=1.)
plt.show()

# %% [markdown]
# ## Hyperparamètres

# %%
# Étude de l'influence du pas d'assimilation
methode = 0
nvarobs = [0,2]
nmem = 30
so2 = 9.e-2
pas_assim_list = [5, 10, 25, 50, 100] # sur 1000 points totaux
rms_errors = []
var_errors = []
times = []

for pas_assim in pas_assim_list:
    time1, xvar1, rms_error, var_error = run_assimilation(methode, nmem, so2, pas_assim, nvarobs)
    rms_errors.append(rms_error)
    var_errors.append(var_error)
    times.append(time1)

# Plot des erreurs RMS et variance en fonction du pas d'assimilation
plt.figure(figsize=(12,8))
plt.subplot(2,1,1)
for i, pas_assim in enumerate(pas_assim_list):
    plt.plot(times[i][25::pas_assim], rms_errors[i], label=f'Pas assim {pas_assim}')
plt.xlabel('Cycle d\'assimilation')
plt.ylabel('Erreur RMS normalisée')
plt.legend()
plt.subplot(2,1,2)
for i, pas_assim in enumerate(pas_assim_list):
    plt.plot(times[i][25::pas_assim], np.log(var_errors[i]), label=f'Pas assim {pas_assim}')
plt.xlabel('Cycle d\'assimilation')
plt.ylabel('log(Variance de l\'ensemble)')
plt.legend()
plt.show()

# %%
# Étude de l'influence du nombre de variables observées
methode = 1
pas_assim = 50
nvarobs_list = [[0], [0,2], [0,1], [1, 2], [0,1,2]]
nmem_list = 30
so2_list = 1e-2
rms_errors = {}
var_errors = {}

for nvarobs in nvarobs_list:
    time1, xvar1, rms_error, var_error = run_assimilation(methode, nmem, so2, pas_assim, nvarobs)
    rms_errors[tuple(nvarobs)] = rms_error
    var_errors[tuple(nvarobs)] = var_error

# Plot des erreurs RMS et variance en fonction du nombre de variables observées
plt.figure(figsize=(12,8))
plt.subplot(2,1,1)
for nvarobs in nvarobs_list:
    plt.plot(time1[25::pas_assim], rms_errors[tuple(nvarobs)], label=f'Obs vars {nvarobs}')
plt.xlabel('Cycle d\'assimilation')
plt.ylabel('Erreur RMS normalisée')
plt.legend()
plt.subplot(2,1,2)
for nvarobs in nvarobs_list:
    plt.plot(time1[25::pas_assim], np.log(var_errors[tuple(nvarobs)]), label=f'Obs vars {nvarobs}')
plt.xlabel('Cycle d\'assimilation')
plt.ylabel('log(Variance de l\'ensemble)')
plt.legend()
plt.show()

# %%
# Influence du nombre de membres de l'ensemble
methode = 0
pas_assim = 20
nvarobs_list = [0, 2]
nmem_list = [5, 10, 20, 50, 100]
so2_list = 9e-2
rms_errors = []
var_errors = []

for nmem in nmem_list:
    time1, xvar1, rms_error, var_error = run_assimilation(methode, nmem, so2_list, pas_assim, nvarobs_list)
    rms_errors.append(rms_error)
    var_errors.append(var_error)

# Plot des erreurs RMS et variance en fonction du nombre de membres
plt.figure(figsize=(12,8))
plt.subplot(2,1,1)
for i, nmem in enumerate(nmem_list):
    plt.plot(time1[25::pas_assim], rms_errors[i], label=f'Nb membres {nmem}')
plt.xlabel('Cycle d\'assimilation')
plt.ylabel('Erreur RMS normalisée')
plt.legend()
plt.subplot(2,1,2)
for i, nmem in enumerate(nmem_list):
    plt.plot(time1[25::pas_assim], np.log(var_errors[i]), label=f'Nb membres {nmem}')
plt.xlabel('Cycle d\'assimilation')
plt.ylabel('log(Variance de l\'ensemble)')
plt.legend()
plt.show()

# %%
# Étude de l'influence de l'erreur d'observation
methode = 0
pas_assim = 50
nvarobs = [0, 2]
nmem = 30
so2_list = [1e-3, 1e-2, 5e-2, 1e-1, 5e-1]
rms_errors = []
var_errors = []

for so2 in so2_list:
    time1, xvar1, rms_error, var_error = run_assimilation(methode, nmem, so2, pas_assim, nvarobs)
    rms_errors.append(rms_error)
    var_errors.append(var_error)

# Plot des erreurs RMS et variance en fonction de so2
plt.figure(figsize=(12,8))
plt.subplot(2,1,1)
for i, so2 in enumerate(so2_list):
    plt.plot(time1[25::pas_assim], rms_errors[i], label=f'so2 {so2}')
plt.xlabel('Cycle d\'assimilation')
plt.ylabel('Erreur RMS normalisée')
plt.legend()
plt.subplot(2,1,2)
for i, so2 in enumerate(so2_list):
    # log scale pour les var
    plt.plot(time1[25::pas_assim], np.log10(var_errors[i]), label=f'so2 {so2}')
plt.xlabel('Cycle d\'assimilation')
plt.ylabel('log(Variance de l\'ensemble)')
plt.legend()
plt.show()

# %%
# Influence de ntilde dans l'EnKF stochastique
methode = 0
pas_assim = 50
nvarobs = [0, 2]
nmem = 30
so2 = 1e-2
ntilde_list = [5, 10, 20, 50, 100]
rms_errors = []
var_errors = []

for ntilde in ntilde_list:
    time1, xvar1, rms_error, var_error = run_assimilation(methode, nmem, so2, pas_assim, nvarobs, ntilde)
    rms_errors.append(rms_error)
    var_errors.append(var_error)

# Plot des erreurs RMS et variance en fonction de ntilde
plt.figure(figsize=(12,8))
plt.subplot(2,1,1)
for i, ntilde in enumerate(ntilde_list):
    plt.plot(time1[25::pas_assim], rms_errors[i], label=f'ntilde {ntilde}')
plt.xlabel('Cycle d\'assimilation')
plt.ylabel('Erreur RMS normalisée')
plt.legend()
plt.subplot(2,1,2)
for i, ntilde in enumerate(ntilde_list):
    plt.plot(time1[25::pas_assim], var_errors[i], label=f'ntilde {ntilde}')
plt.xlabel('Cycle d\'assimilation')
plt.ylabel('Variance de l\'ensemble')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[78], line 12
#       9 var_errors = []
#      11 for ntilde in ntilde_list:
# ---> 12     time1, xvar1, rms_error, var_error = run_assimilation(methode, nmem, so2, pas_assim, nvarobs, ntilde)
#      13     rms_errors.append(rms_error)
#      14     var_errors.append(var_error)
#
# Cell In[77], line 52, in run_assimilation(methode, nmem, so2, pas_assim, nvarobs, ntilde)
#      50 obs_index = np.argwhere( true_time == lorenz_assim.time )
#      51 y=np.transpose(true_state[nvarobs, obs_index, 0] +np.dot(math.sqrt(so2)*np.eye(nobs),np.random.normal(0,1,(nobs,))))
# ---> 52 lorenz_assim.xvar = analysis(lorenz_assim.xvar,y,Robs,H,methode,nobs, ntilde)
#      54 rms_error[ic] = np.sqrt(np.mean((np.mean(lorenz_assim.xvar, axis=1) - true_state[:,obs_index,0].flatten())**2/np.mean(true_state[:,obs_index,0].flatten()**2)))
# ...
